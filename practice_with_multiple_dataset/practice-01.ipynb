# %% [markdown]
# In this practice notebook, I will work with classic **"titanic dataset"**

# %%
import kagglehub

# downloading the dataset from kaggle
path = kagglehub.dataset_download("yasserh/titanic-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# Path to dataset files: C:\Users\gayat\.cache\kagglehub\datasets\yasserh\titanic-dataset\versions\1

# %%
#essential imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %%
#unpacking the dataset
df = pd.read_csv(r"C:\Users\gayat\.cache\kagglehub\datasets\yasserh\titanic-dataset\versions\1\Titanic-Dataset.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#let's see if there are missing values
df.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
#We know there are missing values in Age, Cabin and Embarked
#We'll see the number of missing values
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#We'll handle the "age" column now
#For that, we'll see the relation of age with other numerical columns
fig, axes = plt.subplots(3,3)

axes[0,0].plot(df["Sex"], df["Age"], kind = "scatter")
axes[0,0].set_title("Sex vs Age")

axes[0,1].plot(df["Survived"], df["Age"], kind = "scatter")
axes[0,1].plot("Survived vs Age")

axes[0,2].plot(df["PClass"], df["Age"], kind = "")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 5
#       1 #We'll handle the "age" column now
#       2 #For that, we'll see the relation of age with other numerical columns
#       4 sns.pairplot(data = df, hue = "Sex")
# ----> 5 plt.show()
#
# AttributeError: module 'plotly.express' has no attribute 'show'
