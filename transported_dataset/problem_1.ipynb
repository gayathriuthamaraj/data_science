# %% [markdown]
# **DO NOT RUN ALL; CHANGES IN THE DATASET WILL HAPPEN**

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
test_data = pd.read_csv("test.csv")
test_data
# Out:
#      PassengerId HomePlanet CryoSleep     Cabin    Destination   Age    VIP  \
# 0        0013_01      Earth      True     G/3/S    TRAPPIST-1e  27.0  False
# 1        0018_01      Earth     False     F/4/S    TRAPPIST-1e  19.0  False
# 2        0019_01     Europa      True     C/0/S    55 Cancri e  31.0  False
# 3        0021_01     Europa     False     C/1/S    TRAPPIST-1e  38.0  False
# 4        0023_01      Earth     False     F/5/S    TRAPPIST-1e  20.0  False
# ...          ...        ...       ...       ...            ...   ...    ...
# 4272     9266_02      Earth      True  G/1496/S    TRAPPIST-1e  34.0  False
# 4273     9269_01      Earth     False       NaN    TRAPPIST-1e  42.0  False
# 4274     9271_01       Mars      True   D/296/P    55 Cancri e   NaN  False
# 4275     9273_01     Europa     False   D/297/P            NaN   NaN  False
# 4276     9277_01      Earth      True  G/1498/S  PSO J318.5-22  43.0  False
#
# ...

# %%
train_data = pd.read_csv("train.csv")
train_data.head(25)
# Out:
#    PassengerId HomePlanet CryoSleep  Cabin    Destination   Age    VIP  \
# 0      0001_01     Europa     False  B/0/P    TRAPPIST-1e  39.0  False
# 1      0002_01      Earth     False  F/0/S    TRAPPIST-1e  24.0  False
# 2      0003_01     Europa     False  A/0/S    TRAPPIST-1e  58.0   True
# 3      0003_02     Europa     False  A/0/S    TRAPPIST-1e  33.0  False
# 4      0004_01      Earth     False  F/1/S    TRAPPIST-1e  16.0  False
# 5      0005_01      Earth     False  F/0/P  PSO J318.5-22  44.0  False
# 6      0006_01      Earth     False  F/2/S    TRAPPIST-1e  26.0  False
# 7      0006_02      Earth      True  G/0/S    TRAPPIST-1e  28.0  False
# 8      0007_01      Earth     False  F/3/S    TRAPPIST-1e  35.0  False
# 9      0008_01     Europa      True  B/1/P    55 Cancri e  14.0  False
# 10     0008_02     Europa      True  B/1/P    TRAPPIST-1e  34.0  False
# 11     0008_03     Europa     False  B/1/P    55 Cancri e  45.0  False
# ...

# %%
sample = pd.read_csv("sample_submission.csv")
sample = pd.merge(sample, test_data, on = "PassengerId")
sample
# Out:
#      PassengerId  Transported HomePlanet CryoSleep     Cabin    Destination  \
# 0        0013_01        False      Earth      True     G/3/S    TRAPPIST-1e
# 1        0018_01        False      Earth     False     F/4/S    TRAPPIST-1e
# 2        0019_01        False     Europa      True     C/0/S    55 Cancri e
# 3        0021_01        False     Europa     False     C/1/S    TRAPPIST-1e
# 4        0023_01        False      Earth     False     F/5/S    TRAPPIST-1e
# ...          ...          ...        ...       ...       ...            ...
# 4272     9266_02        False      Earth      True  G/1496/S    TRAPPIST-1e
# 4273     9269_01        False      Earth     False       NaN    TRAPPIST-1e
# 4274     9271_01        False       Mars      True   D/296/P    55 Cancri e
# 4275     9273_01        False     Europa     False   D/297/P            NaN
# 4276     9277_01        False      Earth      True  G/1498/S  PSO J318.5-22
#
# ...

# %%
train_data.describe()
# Out:
#                Age   RoomService     FoodCourt  ShoppingMall           Spa  \
# count  8514.000000   8512.000000   8510.000000   8485.000000   8510.000000
# mean     28.827930    224.687617    458.077203    173.729169    311.138778
# std      14.489021    666.717663   1611.489240    604.696458   1136.705535
# min       0.000000      0.000000      0.000000      0.000000      0.000000
# 25%      19.000000      0.000000      0.000000      0.000000      0.000000
# 50%      27.000000      0.000000      0.000000      0.000000      0.000000
# 75%      38.000000     47.000000     76.000000     27.000000     59.000000
# max      79.000000  14327.000000  29813.000000  23492.000000  22408.000000
#
#              VRDeck
# count   8505.000000
# mean     304.854791
# std     1145.717189
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%       46.000000
# max    24133.000000

# %%
train_data.isnull().any()
# Out:
# PassengerId     False
# HomePlanet       True
# CryoSleep        True
# Cabin            True
# Destination      True
# Age              True
# VIP              True
# RoomService      True
# FoodCourt        True
# ShoppingMall     True
# Spa              True
# VRDeck           True
# Name             True
# Transported     False
# dtype: bool

# %%
dropped_data = train_data.dropna()
dropped_data
# Out:
#      PassengerId HomePlanet CryoSleep     Cabin    Destination   Age    VIP  \
# 0        0001_01     Europa     False     B/0/P    TRAPPIST-1e  39.0  False
# 1        0002_01      Earth     False     F/0/S    TRAPPIST-1e  24.0  False
# 2        0003_01     Europa     False     A/0/S    TRAPPIST-1e  58.0   True
# 3        0003_02     Europa     False     A/0/S    TRAPPIST-1e  33.0  False
# 4        0004_01      Earth     False     F/1/S    TRAPPIST-1e  16.0  False
# ...          ...        ...       ...       ...            ...   ...    ...
# 8688     9276_01     Europa     False    A/98/P    55 Cancri e  41.0   True
# 8689     9278_01      Earth      True  G/1499/S  PSO J318.5-22  18.0  False
# 8690     9279_01      Earth     False  G/1500/S    TRAPPIST-1e  26.0  False
# 8691     9280_01     Europa     False   E/608/S    55 Cancri e  32.0  False
# 8692     9280_02     Europa     False   E/608/S    TRAPPIST-1e  44.0  False
#
# ...

# %%
dropped_data.describe()
# Out:
#                Age  RoomService     FoodCourt  ShoppingMall           Spa  \
# count  6606.000000  6606.000000   6606.000000   6606.000000   6606.000000
# mean     28.894036   222.991674    478.958523    178.356494    313.161520
# std      14.533429   644.987936   1678.592291    576.328407   1144.016291
# min       0.000000     0.000000      0.000000      0.000000      0.000000
# 25%      19.000000     0.000000      0.000000      0.000000      0.000000
# 50%      27.000000     0.000000      0.000000      0.000000      0.000000
# 75%      38.000000    49.000000     82.750000     30.000000     65.000000
# max      79.000000  9920.000000  29813.000000  12253.000000  22408.000000
#
#              VRDeck
# count   6606.000000
# mean     303.780048
# std     1127.142166
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%       52.000000
# max    20336.000000

# %%
print(dropped_data['HomePlanet'].unique())
print(dropped_data['Destination'].unique())
# Out:
# ['Europa' 'Earth' 'Mars']
# ['TRAPPIST-1e' 'PSO J318.5-22' '55 Cancri e']

# %%
dropped_data = pd.get_dummies(dropped_data, columns = ['HomePlanet'])
dropped_data = pd.get_dummies(dropped_data, columns = ['Destination'])

# %%
dropped_data.columns
# Out:
# Index(['PassengerId', 'CryoSleep', 'Cabin', 'Age', 'VIP', 'RoomService',
#        'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck', 'Name', 'Transported',
#        'HomePlanet_Earth', 'HomePlanet_Europa', 'HomePlanet_Mars',
#        'Destination_55 Cancri e', 'Destination_PSO J318.5-22',
#        'Destination_TRAPPIST-1e'],
#       dtype='object')

# %%
from sklearn.tree import DecisionTreeClassifier

y = dropped_data['Transported']

X = dropped_data[['CryoSleep', 'Age', 'VIP', 'RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck', 'HomePlanet_Earth', 'HomePlanet_Europa', 'HomePlanet_Mars','Destination_55 Cancri e', 'Destination_PSO J318.5-22','Destination_TRAPPIST-1e']]

# %%
X.head()
# Out:
#   CryoSleep   Age    VIP  RoomService  FoodCourt  ShoppingMall     Spa  \
# 0     False  39.0  False          0.0        0.0           0.0     0.0
# 1     False  24.0  False        109.0        9.0          25.0   549.0
# 2     False  58.0   True         43.0     3576.0           0.0  6715.0
# 3     False  33.0  False          0.0     1283.0         371.0  3329.0
# 4     False  16.0  False        303.0       70.0         151.0   565.0
#
#    VRDeck  HomePlanet_Earth  HomePlanet_Europa  HomePlanet_Mars  \
# 0     0.0             False               True            False
# 1    44.0              True              False            False
# 2    49.0             False               True            False
# 3   193.0             False               True            False
# 4     2.0              True              False            False
#
#    Destination_55 Cancri e  Destination_PSO J318.5-22  Destination_TRAPPIST-1e
# ...

# %%
iowa_model = DecisionTreeClassifier(random_state=0)
iowa_model.fit(X,y)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
predictions = iowa_model.predict(X)
predictions
# Out:
# array([False,  True, False, ...,  True, False,  True])

# %%
y.head()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# Name: Transported, dtype: bool

# %%
test_data = pd.get_dummies(test_data, columns = ['HomePlanet'])
test_data = pd.get_dummies(test_data, columns = ['Destination'])

# %%
test_data = test_data.drop(columns=['Cabin', 'Name', 'PassengerId'])  # keep only features

# %%
original_predictions = iowa_model.predict(test_data)
print(original_predictions.size)
# Out:
# 4277

# %%
from sklearn.metrics import accuracy_score

acc = accuracy_score(y, predictions)
acc
# Out:
# 0.9335452618831366

# %%
test_acc = accuracy_score(sample['Transported'], original_predictions)
test_acc
# Out:
# 0.4594341828384382
